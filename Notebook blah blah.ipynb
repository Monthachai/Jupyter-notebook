# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name: Monthachai**
#
# **Current occupation: I'm a student.**

# %% [markdown]
# *I am interested in data science because actually there are lots of data in this world that humans are involved, being able to manipulate data is what intrigued me.*

# %% [markdown]
# ### My code in the next cell it's suppose to display an output of "2"

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# - Good Luck
#      - Everyone
# ___
#
# 1. Lets go
# 2. Together
# ___
#
# ![what_is_image_Processing.webp](attachment:what_is_image_Processing.webp)
